# %%
# IMPORT

import pandas as pd
import pylab as plt
import seaborn as sns
import numpy as np
import h2o

from sklearn.model_selection import train_test_split
from h2o.automl import H2OAutoML
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2

import warnings
warnings.filterwarnings('ignore')

# %%
# LINEAR REGRESSION MODELS

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
lasso=Lasso()
ridge=Ridge()
elastic=ElasticNet()
le=LabelEncoder

from sklearn.svm import SVR
svr=SVR()

from sklearn.ensemble import RandomForestRegressor as RFR  
from sklearn.tree import ExtraTreeRegressor as ETR
rfr=RFR()
etr=ETR()

from sklearn.ensemble import GradientBoostingRegressor as GBR
from xgboost import XGBRegressor as XGBR
from catboost import CatBoostRegressor as CTR
from lightgbm import LGBMRegressor as LGBMR
gbr=GBR()
xgbr=XGBR()
ctr=CTR()
lgbmr=LGBMR()

# %%
# LOAD CSVs

train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')
sample = pd.read_csv('../data/sample.csv')

# %%
train1 = train.copy()
test1 = test.copy()
sample1 = sample.copy()

# %%
le = LabelEncoder()

for c in train1.columns:
    
    if c=='host_location' or c=='host_verifications':
        
        le.fit(train1[c].astype(str))
        
        train1[c]=le.transform(train1[c].astype(str))

# %%
train1=pd.get_dummies(train1, columns=['property_type'], drop_first=True)
lista = [col for col in train1.columns if 'property_type' in col]
train1[lista] = train1[lista].astype(float)

train1=pd.get_dummies(train1, columns=['bathrooms_text'], drop_first=True)
lista = [col for col in train1.columns if 'bathrooms_text' in col]
train1[lista] = train1[lista].astype(float)

train1=pd.get_dummies(train1, columns=['neighbourhood_cleansed'], drop_first=True)
lista = [col for col in train1.columns if 'neighbourhood_cleansed' in col]
train1[lista] = train1[lista].astype(float)

train1=pd.get_dummies(train1, columns=['host_neighbourhood'], drop_first=True)
lista = [col for col in train1.columns if 'host_neighbourhood' in col]
train1[lista] = train1[lista].astype(float)

'''train1=pd.get_dummies(train1, columns=['amenities'], drop_first=True)
lista = [col for col in train1.columns if 'amenities' in col]
train1[lista] = train1[lista].astype(float)'''
# Out:
# "train1=pd.get_dummies(train1, columns=['amenities'], drop_first=True)\nlista = [col for col in train1.columns if 'amenities' in col]\ntrain1[lista] = train1[lista].astype(float)"

# %%
def trans(train1):    
    
    if 'price' in train1.columns:
    
        # CHANGE PRICE COLUMN POSITION

        aux = train1.price

        train1 = train1.drop('price',axis=1)

        train1.insert(1, 'price', aux)

        train1 = train1[train1.price<=6000]

    # TRANSFORM COLUMNS

    train1.host_acceptance_rate = train1.host_acceptance_rate.str.replace('%','').astype(float)/100

    train1.host_response_rate = train1.host_response_rate.str.replace('%','').astype(float)/100

    # DROP TRAIN COLUMNS

    col_importance = ['property_type','neighbourhood_cleansed','host_verifications','host_neighbourhood',
                      'availability_365','longitude','bedrooms','accommodates','host_acceptance_rate','host_location',
                      'minimum_maximum_nights','availability_90','review_scores_value','host_total_listings_count',
                      'availability_30','number_of_reviews','host_id','first_review','bathrooms_text','host_response_rate']

    col_classification = [c for c in train1.columns if np.dtype(train1[c]) is np.dtype(np.object)]

    col_noutil = ['listing_url','scrape_id','last_scraped','name','description','neighborhood_overview','picture_url',
                  'host_url']

    train1 = train1.dropna(axis=1, how='all')
    train1 = train1.drop(col_noutil, axis=1)
    train1 = train1.drop(columns=[c for c in train1 if c in col_classification and c!='price' and c!='host_acceptance_rate'
                                  and c!='host_response_rate'], axis=1)
    # No correlación con price
    train1 = train1.drop(columns='id', axis=1)
    # >0.9 Correlación con otras columnas
    train1 = train1.drop('minimum_nights', axis=1)
    train1 = train1.drop('minimum_minimum_nights', axis=1)
    train1 = train1.drop('minimum_nights_avg_ntm', axis=1)
    train1 = train1.drop('availability_90', axis=1)
    train1 = train1.drop('availability_60', axis=1)
    train1 = train1.drop('host_total_listings_count', axis=1)
    train1 = train1.drop('host_listings_count', axis=1)

    # FILLNA columnas numéricas con sus medias

    col_somenull = [c for c in train1.columns if (train1[c].isnull().sum()>0)]

    for c in col_somenull:

        # Probar a cambiar mean por mode o median
        train1[c].fillna(round(train1[c].median()), inplace=True)
        
    return train1

train1 = trans(train1)

# %%
le = LabelEncoder()

for c in test1.columns:
    
    if c=='host_location' or c=='host_verifications':
        
        le.fit(test1[c].astype(str))
        
        test1[c]=le.transform(test1[c].astype(str))

test1=pd.get_dummies(test1, columns=['property_type'], drop_first=True)
lista = [col for col in test1.columns if 'property_type' in col]
test1[lista] = test1[lista].astype(float)

test1=pd.get_dummies(test1, columns=['host_neighbourhood'], drop_first=True)
lista = [col for col in test1.columns if 'host_neighbourhood' in col]
test1[lista] = test1[lista].astype(float)

test1=pd.get_dummies(test1, columns=['bathrooms_text'], drop_first=True)
lista = [col for col in test1.columns if 'bathrooms_text' in col]
test1[lista] = test1[lista].astype(float)

test1=pd.get_dummies(test1, columns=['neighbourhood_cleansed'], drop_first=True)
lista = [col for col in test1.columns if 'neighbourhood_cleansed' in col]
test1[lista] = test1[lista].astype(float)

test1 = trans(test1)

# %%
'''# TRANSFORM COLUMNS

test1.host_acceptance_rate = test1.host_acceptance_rate.str.replace('%','').astype(float)/100

test1.host_response_rate = test1.host_response_rate.str.replace('%','').astype(float)/100

# DROP TRAIN COLUMNS

col_importance = ['price','property_type','neighbourhood_cleansed','host_verifications','host_neighbourhood',
                  'availability_365','longitude','bedrooms','accommodates','host_acceptance_rate','host_location',
                  'minimum_maximum_nights','availability_90','review_scores_value','host_total_listings_count',
                  'availability_30','number_of_reviews','host_id','first_review','bathrooms_text','host_response_rate']

col_classification = [c for c in test1.columns if np.dtype(test1[c]) is np.dtype(np.object)]

col_noutil = ['listing_url','scrape_id','last_scraped','name','description','neighborhood_overview','picture_url',
              'host_url']

test1 = test1.dropna(axis=1, how='all')
test1 = test1.drop(col_noutil, axis=1)
test1 = test1.drop(columns=[c for c in test1 if c in col_classification and c!='price' and c!='host_acceptance_rate'
                              and c!='host_response_rate'], axis=1)
# Sin correlación con price
test1 = test1.drop(columns='id', axis=1)
# Mucha correlación con otras columnas
test1 = test1.drop('minimum_nights', axis=1)
test1 = test1.drop('minimum_minimum_nights', axis=1)
test1 = test1.drop('minimum_nights_avg_ntm', axis=1)
test1 = test1.drop('availability_90', axis=1)
test1 = test1.drop('availability_60', axis=1)

# FILLNA columnas numéricas con sus medias

col_somenull = [c for c in test1.columns if test1[c].isnull().sum()>0]

for c in col_somenull:
    
    # Probar a cambiar mean por mode o median
    test1[c].fillna(round(test1[c].median()), inplace=True)'''
# Out:
# "# TRANSFORM COLUMNS\n\ntest1.host_acceptance_rate = test1.host_acceptance_rate.str.replace('%','').astype(float)/100\n\ntest1.host_response_rate = test1.host_response_rate.str.replace('%','').astype(float)/100\n\n# DROP TRAIN COLUMNS\n\ncol_importance = ['price','property_type','neighbourhood_cleansed','host_verifications','host_neighbourhood',\n                  'availability_365','longitude','bedrooms','accommodates','host_acceptance_rate','host_location',\n                  'minimum_maximum_nights','availability_90','review_scores_value','host_total_listings_count',\n                  'availability_30','number_of_reviews','host_id','first_review','bathrooms_text','host_response_rate']\n\ncol_classification = [c for c in test1.columns if np.dtype(test1[c]) is np.dtype(np.object)]\n\ncol_noutil = ['listing_url','scrape_id','last_scraped','name','description','neighborhood_overview','picture_url',\n              'host_url']\n\ntest1 = test1.dropna(axis=1, how='all')\ntest1 = test1.drop(col_noutil, axis=1)\ntest1 = test1.drop(columns=[c for c in test1 if c in col_classification and c!='price' and c!='host_acceptance_rate'\n                              and c!='host_response_rate'], axis=1)\n# Sin correlación con price\ntest1 = test1.drop(columns='id', axis=1)\n# Mucha correlación con otras columnas\ntest1 = test1.drop('minimum_nights', axis=1)\ntest1 = test1.drop('minimum_minimum_nights', axis=1)\ntest1 = test1.drop('minimum_nights_avg_ntm', axis=1)\ntest1 = test1.drop('availability_90', axis=1)\ntest1 = test1.drop('availability_60', axis=1)\n\n# FILLNA columnas numéricas con sus medias\n\ncol_somenull = [c for c in test1.columns if test1[c].isnull().sum()>0]\n\nfor c in col_somenull:\n    \n    # Probar a cambiar mean por mode o median\n    test1[c].fillna(round(test1[c].median()), inplace=True)"

# %%
X = train1.drop('price', axis=1)

y = train1.price

X.shape, y.shape
# Out:
# ((4165, 176), (4165,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2, train_size=0.8,
                                                    random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3332, 176), (833, 176), (3332,), (833,))

# %%
# RMSE POR MODELO
# modelo que da error: lgbmr
models = [lasso, ridge, elastic, svr, rfr, etr, gbr, xgbr, ctr]

for m in models:
    
    m.fit(X_train, y_train)
    y_pred = m.predict(X_test)
    
    print(f'RMSE Model {m}: {mse(y_test, y_pred, squared=False)}')
    print(f'R2 Model {m}: {r2(y_test, y_pred)}')
# Out:
# RMSE Model Lasso(): 80.12018312076914
# R2 Model Lasso(): 0.5138856827877281
# RMSE Model Ridge(): 77.30762001562303
# R2 Model Ridge(): 0.5474160458747346
# RMSE Model ElasticNet(): 84.20921773585764
# R2 Model ElasticNet(): 0.4630005860339582
# RMSE Model SVR(): 118.86979896430756
# R2 Model SVR(): -0.07003406096333276
# RMSE Model RandomForestRegressor(): 75.72997589600489
# R2 Model RandomForestRegressor(): 0.5656996463829149
# RMSE Model ExtraTreeRegressor(): 106.94163176724963
# R2 Model ExtraTreeRegressor(): 0.13393964482384524
# RMSE Model GradientBoostingRegressor(): 78.09025284719479
# R2 Model GradientBoostingRegressor(): 0.5382060872703339
# RMSE Model XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None): 78.98845728411555
# R2 Model XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None): 0.5275217628091154
# Learning rate set to 0.048355
# 0:	learn: 114.9083692	total: 303ms	remaining: 5m 2s
# 1:	learn: 113.2591655	total: 315ms	remaining: 2m 37s
# 2:	learn: 111.7517102	total: 327ms	remaining: 1m 48s
# 3:	learn: 110.5086374	total: 339ms	remaining: 1m 24s
# 4:	learn: 109.2853421	total: 350ms	remaining: 1m 9s
# 5:	learn: 108.0081626	total: 361ms	remaining: 59.8s
# 6:	learn: 106.9697599	total: 372ms	remaining: 52.8s
# 7:	learn: 105.7933639	total: 383ms	remaining: 47.5s
# 8:	learn: 104.6996656	total: 394ms	remaining: 43.4s
# 9:	learn: 103.7119487	total: 410ms	remaining: 40.6s
# 10:	learn: 102.9278241	total: 422ms	remaining: 37.9s
# 11:	learn: 101.8458296	total: 435ms	remaining: 35.8s
# 12:	learn: 100.9922651	total: 446ms	remaining: 33.9s
# 13:	learn: 100.1916965	total: 458ms	remaining: 32.2s
# 14:	learn: 99.3295200	total: 469ms	remaining: 30.8s
# 15:	learn: 98.5071054	total: 481ms	remaining: 29.6s
# 16:	learn: 97.8125604	total: 492ms	remaining: 28.4s
# 17:	learn: 97.2248372	total: 505ms	remaining: 27.6s
# 18:	learn: 96.7169893	total: 518ms	remaining: 26.7s
# 19:	learn: 96.1537850	total: 530ms	remaining: 26s
# 20:	learn: 95.5697084	total: 542ms	remaining: 25.3s
# 21:	learn: 95.1714390	total: 554ms	remaining: 24.6s
# 22:	learn: 94.5787805	total: 568ms	remaining: 24.1s
# 23:	learn: 94.0633340	total: 584ms	remaining: 23.8s
# 24:	learn: 93.5767245	total: 602ms	remaining: 23.5s
# 25:	learn: 93.0060560	total: 618ms	remaining: 23.2s
# 26:	learn: 92.6409410	total: 631ms	remaining: 22.7s
# 27:	learn: 92.2445994	total: 643ms	remaining: 22.3s
# 28:	learn: 91.8307221	total: 654ms	remaining: 21.9s
# 29:	learn: 91.3723120	total: 666ms	remaining: 21.5s
# 30:	learn: 91.0393841	total: 678ms	remaining: 21.2s
# 31:	learn: 90.5694764	total: 690ms	remaining: 20.9s
# 32:	learn: 90.1272011	total: 703ms	remaining: 20.6s
# 33:	learn: 89.7911938	total: 714ms	remaining: 20.3s
# 34:	learn: 89.4442536	total: 725ms	remaining: 20s
# 35:	learn: 89.0209969	total: 735ms	remaining: 19.7s
# 36:	learn: 88.7447874	total: 747ms	remaining: 19.4s
# 37:	learn: 88.5081437	total: 758ms	remaining: 19.2s
# 38:	learn: 88.1023261	total: 768ms	remaining: 18.9s
# 39:	learn: 87.8734062	total: 778ms	remaining: 18.7s
# 40:	learn: 87.4949073	total: 789ms	remaining: 18.5s
# 41:	learn: 87.2659896	total: 799ms	remaining: 18.2s
# 42:	learn: 86.9748229	total: 811ms	remaining: 18.1s
# 43:	learn: 86.6520252	total: 822ms	remaining: 17.9s
# 44:	learn: 86.4322153	total: 835ms	remaining: 17.7s
# 45:	learn: 86.1236711	total: 851ms	remaining: 17.6s
# 46:	learn: 85.9307886	total: 868ms	remaining: 17.6s
# 47:	learn: 85.5374347	total: 885ms	remaining: 17.6s
# 48:	learn: 85.3396727	total: 903ms	remaining: 17.5s
# 49:	learn: 84.9448823	total: 925ms	remaining: 17.6s
# 50:	learn: 84.6832953	total: 942ms	remaining: 17.5s
# 51:	learn: 84.4621566	total: 969ms	remaining: 17.7s
# 52:	learn: 84.2451879	total: 988ms	remaining: 17.7s
# 53:	learn: 83.9147249	total: 1.01s	remaining: 17.7s
# 54:	learn: 83.6576968	total: 1.03s	remaining: 17.7s
# 55:	learn: 83.5121080	total: 1.05s	remaining: 17.7s
# 56:	learn: 83.3474303	total: 1.07s	remaining: 17.8s
# 57:	learn: 83.2047447	total: 1.09s	remaining: 17.8s
# 58:	learn: 83.0157750	total: 1.11s	remaining: 17.8s
# 59:	learn: 82.8035049	total: 1.15s	remaining: 17.9s
# 60:	learn: 82.6696006	total: 1.16s	remaining: 17.9s
# 61:	learn: 82.4718632	total: 1.18s	remaining: 17.9s
# 62:	learn: 82.2802977	total: 1.2s	remaining: 17.8s
# 63:	learn: 82.1236000	total: 1.21s	remaining: 17.7s
# 64:	learn: 82.0042767	total: 1.23s	remaining: 17.7s
# 65:	learn: 81.7232177	total: 1.25s	remaining: 17.7s
# 66:	learn: 81.6178500	total: 1.32s	remaining: 18.4s
# 67:	learn: 81.5694344	total: 1.35s	remaining: 18.5s
# 68:	learn: 81.3863698	total: 1.37s	remaining: 18.5s
# 69:	learn: 81.3210166	total: 1.39s	remaining: 18.5s
# 70:	learn: 81.0683188	total: 1.4s	remaining: 18.4s
# 71:	learn: 80.8724519	total: 1.42s	remaining: 18.3s
# 72:	learn: 80.6874984	total: 1.43s	remaining: 18.1s
# 73:	learn: 80.5876185	total: 1.44s	remaining: 18s
# 74:	learn: 80.3092279	total: 1.45s	remaining: 17.9s
# 75:	learn: 80.2468461	total: 1.46s	remaining: 17.8s
# 76:	learn: 80.0904437	total: 1.48s	remaining: 17.7s
# 77:	learn: 79.7871133	total: 1.49s	remaining: 17.6s
# 78:	learn: 79.6189787	total: 1.5s	remaining: 17.5s
# 79:	learn: 79.4983207	total: 1.51s	remaining: 17.4s
# 80:	learn: 79.2921398	total: 1.52s	remaining: 17.3s
# 81:	learn: 79.2087832	total: 1.54s	remaining: 17.2s
# 82:	learn: 79.0764735	total: 1.55s	remaining: 17.1s
# 83:	learn: 78.9945433	total: 1.56s	remaining: 17s
# 84:	learn: 78.9383773	total: 1.57s	remaining: 16.9s
# 85:	learn: 78.7611334	total: 1.58s	remaining: 16.8s
# 86:	learn: 78.7153563	total: 1.59s	remaining: 16.7s
# 87:	learn: 78.6265356	total: 1.61s	remaining: 16.7s
# 88:	learn: 78.5194031	total: 1.62s	remaining: 16.6s
# 89:	learn: 78.3435089	total: 1.63s	remaining: 16.5s
# 90:	learn: 78.2837514	total: 1.64s	remaining: 16.4s
# 91:	learn: 78.2306819	total: 1.65s	remaining: 16.3s
# 92:	learn: 78.0370433	total: 1.67s	remaining: 16.3s
# 93:	learn: 77.9036606	total: 1.68s	remaining: 16.2s
# 94:	learn: 77.7569393	total: 1.69s	remaining: 16.1s
# 95:	learn: 77.5717953	total: 1.7s	remaining: 16s
# 96:	learn: 77.5174965	total: 1.71s	remaining: 16s
# 97:	learn: 77.4233384	total: 1.73s	remaining: 15.9s
# 98:	learn: 77.3092657	total: 1.74s	remaining: 15.8s
# 99:	learn: 77.2754091	total: 1.75s	remaining: 15.7s
# 100:	learn: 77.0812246	total: 1.76s	remaining: 15.7s
# 101:	learn: 76.9334750	total: 1.77s	remaining: 15.6s
# 102:	learn: 76.8379479	total: 1.78s	remaining: 15.5s
# 103:	learn: 76.7253762	total: 1.79s	remaining: 15.5s
# 104:	learn: 76.6620310	total: 1.81s	remaining: 15.4s
# 105:	learn: 76.5247149	total: 1.82s	remaining: 15.3s
# 106:	learn: 76.3297205	total: 1.83s	remaining: 15.3s
# 107:	learn: 76.2268262	total: 1.84s	remaining: 15.2s
# 108:	learn: 76.0444742	total: 1.86s	remaining: 15.2s
# 109:	learn: 76.0026234	total: 1.89s	remaining: 15.3s
# 110:	learn: 75.9286292	total: 1.9s	remaining: 15.2s
# 111:	learn: 75.7720286	total: 1.91s	remaining: 15.2s
# 112:	learn: 75.6905761	total: 1.93s	remaining: 15.1s
# 113:	learn: 75.5952994	total: 1.94s	remaining: 15.1s
# 114:	learn: 75.4148638	total: 1.95s	remaining: 15s
# 115:	learn: 75.2568478	total: 1.96s	remaining: 15s
# 116:	learn: 75.1390423	total: 1.98s	remaining: 14.9s
# 117:	learn: 74.9574313	total: 1.99s	remaining: 14.8s
# 118:	learn: 74.8996095	total: 2s	remaining: 14.8s
# 119:	learn: 74.7146560	total: 2.01s	remaining: 14.7s
# 120:	learn: 74.6166574	total: 2.02s	remaining: 14.7s
# 121:	learn: 74.5246912	total: 2.03s	remaining: 14.6s
# 122:	learn: 74.4331401	total: 2.04s	remaining: 14.5s
# 123:	learn: 74.2531647	total: 2.05s	remaining: 14.5s
# 124:	learn: 74.1169252	total: 2.06s	remaining: 14.4s
# 125:	learn: 74.0133577	total: 2.07s	remaining: 14.4s
# 126:	learn: 73.9941584	total: 2.08s	remaining: 14.3s
# 127:	learn: 73.8605619	total: 2.09s	remaining: 14.3s
# 128:	learn: 73.7902844	total: 2.11s	remaining: 14.2s
# 129:	learn: 73.7045677	total: 2.12s	remaining: 14.2s
# 130:	learn: 73.5901748	total: 2.13s	remaining: 14.1s
# 131:	learn: 73.5183301	total: 2.14s	remaining: 14.1s
# 132:	learn: 73.3953440	total: 2.15s	remaining: 14s
# 133:	learn: 73.3382306	total: 2.17s	remaining: 14s
# 134:	learn: 73.2746326	total: 2.18s	remaining: 14s
# 135:	learn: 73.1301339	total: 2.19s	remaining: 13.9s
# 136:	learn: 73.0340461	total: 2.2s	remaining: 13.9s
# 137:	learn: 72.9162097	total: 2.21s	remaining: 13.8s
# 138:	learn: 72.8991482	total: 2.23s	remaining: 13.8s
# 139:	learn: 72.8299557	total: 2.24s	remaining: 13.8s
# 140:	learn: 72.7529800	total: 2.26s	remaining: 13.8s
# 141:	learn: 72.6525293	total: 2.28s	remaining: 13.8s
# 142:	learn: 72.4746771	total: 2.31s	remaining: 13.8s
# 143:	learn: 72.4075578	total: 2.34s	remaining: 13.9s
# 144:	learn: 72.3712279	total: 2.36s	remaining: 13.9s
# 145:	learn: 72.2689508	total: 2.38s	remaining: 13.9s
# 146:	learn: 72.2364264	total: 2.42s	remaining: 14s
# 147:	learn: 72.1359178	total: 2.43s	remaining: 14s
# 148:	learn: 71.9869538	total: 2.45s	remaining: 14s
# 149:	learn: 71.8326377	total: 2.46s	remaining: 13.9s
# 150:	learn: 71.7292126	total: 2.47s	remaining: 13.9s
# 151:	learn: 71.6953152	total: 2.48s	remaining: 13.9s
# 152:	learn: 71.5695339	total: 2.5s	remaining: 13.8s
# 153:	learn: 71.4734373	total: 2.51s	remaining: 13.8s
# 154:	learn: 71.3686600	total: 2.52s	remaining: 13.7s
# 155:	learn: 71.2596515	total: 2.53s	remaining: 13.7s
# 156:	learn: 71.1731655	total: 2.54s	remaining: 13.6s
# 157:	learn: 71.0295805	total: 2.55s	remaining: 13.6s
# 158:	learn: 70.9600359	total: 2.56s	remaining: 13.5s
# 159:	learn: 70.8794587	total: 2.57s	remaining: 13.5s
# 160:	learn: 70.7877883	total: 2.58s	remaining: 13.5s
# 161:	learn: 70.7089837	total: 2.6s	remaining: 13.4s
# 162:	learn: 70.6035547	total: 2.61s	remaining: 13.4s
# 163:	learn: 70.4781688	total: 2.62s	remaining: 13.4s
# 164:	learn: 70.4333695	total: 2.63s	remaining: 13.3s
# 165:	learn: 70.3368922	total: 2.64s	remaining: 13.3s
# 166:	learn: 70.2056899	total: 2.65s	remaining: 13.2s
# 167:	learn: 70.1599556	total: 2.66s	remaining: 13.2s
# 168:	learn: 70.1155487	total: 2.67s	remaining: 13.1s
# 169:	learn: 69.9345208	total: 2.68s	remaining: 13.1s
# 170:	learn: 69.8540999	total: 2.69s	remaining: 13.1s
# 171:	learn: 69.7847300	total: 2.71s	remaining: 13s
# 172:	learn: 69.7598534	total: 2.72s	remaining: 13s
# 173:	learn: 69.6974514	total: 2.73s	remaining: 13s
# 174:	learn: 69.5980023	total: 2.74s	remaining: 12.9s
# 175:	learn: 69.5475159	total: 2.76s	remaining: 12.9s
# 176:	learn: 69.4427763	total: 2.78s	remaining: 12.9s
# 177:	learn: 69.3199655	total: 2.79s	remaining: 12.9s
# 178:	learn: 69.2021833	total: 2.81s	remaining: 12.9s
# 179:	learn: 69.1781319	total: 2.83s	remaining: 12.9s
# 180:	learn: 69.1412845	total: 2.84s	remaining: 12.9s
# 181:	learn: 69.0157024	total: 2.85s	remaining: 12.8s
# 182:	learn: 68.9132319	total: 2.86s	remaining: 12.8s
# 183:	learn: 68.8378375	total: 2.88s	remaining: 12.8s
# 184:	learn: 68.6821946	total: 2.88s	remaining: 12.7s
# 185:	learn: 68.5897848	total: 2.9s	remaining: 12.7s
# 186:	learn: 68.5041436	total: 2.91s	remaining: 12.7s
# 187:	learn: 68.4126247	total: 2.92s	remaining: 12.6s
# 188:	learn: 68.3901123	total: 2.93s	remaining: 12.6s
# 189:	learn: 68.3442754	total: 2.94s	remaining: 12.5s
# 190:	learn: 68.2526156	total: 2.95s	remaining: 12.5s
# 191:	learn: 68.2087896	total: 2.96s	remaining: 12.5s
# 192:	learn: 68.1887325	total: 2.97s	remaining: 12.4s
# 193:	learn: 68.0946686	total: 2.98s	remaining: 12.4s
# 194:	learn: 68.0179416	total: 2.99s	remaining: 12.4s
# 195:	learn: 67.9267401	total: 3s	remaining: 12.3s
# 196:	learn: 67.8117687	total: 3.01s	remaining: 12.3s
# 197:	learn: 67.6632674	total: 3.03s	remaining: 12.3s
# 198:	learn: 67.5732407	total: 3.07s	remaining: 12.4s
# 199:	learn: 67.4722981	total: 3.08s	remaining: 12.3s
# 200:	learn: 67.3349400	total: 3.1s	remaining: 12.3s
# 201:	learn: 67.2746307	total: 3.12s	remaining: 12.3s
# 202:	learn: 67.2170474	total: 3.14s	remaining: 12.3s
# 203:	learn: 67.1223752	total: 3.16s	remaining: 12.3s
# 204:	learn: 67.0721344	total: 3.17s	remaining: 12.3s
# 205:	learn: 66.9792763	total: 3.19s	remaining: 12.3s
# 206:	learn: 66.9161613	total: 3.2s	remaining: 12.3s
# 207:	learn: 66.8674311	total: 3.21s	remaining: 12.2s
# 208:	learn: 66.8310923	total: 3.22s	remaining: 12.2s
# 209:	learn: 66.7241080	total: 3.23s	remaining: 12.2s
# 210:	learn: 66.6413157	total: 3.25s	remaining: 12.1s
# 211:	learn: 66.5373886	total: 3.26s	remaining: 12.1s
# 212:	learn: 66.4560160	total: 3.27s	remaining: 12.1s
# 213:	learn: 66.3614368	total: 3.28s	remaining: 12s
# 214:	learn: 66.2911192	total: 3.29s	remaining: 12s
# 215:	learn: 66.2706028	total: 3.3s	remaining: 12s
# 216:	learn: 66.2551539	total: 3.31s	remaining: 11.9s
# 217:	learn: 66.1171866	total: 3.32s	remaining: 11.9s
# 218:	learn: 66.0947112	total: 3.33s	remaining: 11.9s
# 219:	learn: 66.0235335	total: 3.34s	remaining: 11.8s
# 220:	learn: 65.9160013	total: 3.35s	remaining: 11.8s
# 221:	learn: 65.8312125	total: 3.36s	remaining: 11.8s
# 222:	learn: 65.7882270	total: 3.37s	remaining: 11.7s
# 223:	learn: 65.7428077	total: 3.38s	remaining: 11.7s
# 224:	learn: 65.7136763	total: 3.39s	remaining: 11.7s
# 225:	learn: 65.6855999	total: 3.4s	remaining: 11.6s
# 226:	learn: 65.6268264	total: 3.41s	remaining: 11.6s
# 227:	learn: 65.4729309	total: 3.42s	remaining: 11.6s
# 228:	learn: 65.4420715	total: 3.43s	remaining: 11.5s
# 229:	learn: 65.4220513	total: 3.44s	remaining: 11.5s
# 230:	learn: 65.3279534	total: 3.44s	remaining: 11.5s
# 231:	learn: 65.2442128	total: 3.46s	remaining: 11.4s
# 232:	learn: 65.2237234	total: 3.46s	remaining: 11.4s
# 233:	learn: 65.1678463	total: 3.47s	remaining: 11.4s
# 234:	learn: 65.0919170	total: 3.48s	remaining: 11.3s
# 235:	learn: 65.0241155	total: 3.49s	remaining: 11.3s
# 236:	learn: 65.0114659	total: 3.5s	remaining: 11.3s
# 237:	learn: 64.9230120	total: 3.51s	remaining: 11.2s
# 238:	learn: 64.8418697	total: 3.52s	remaining: 11.2s
# 239:	learn: 64.7459684	total: 3.53s	remaining: 11.2s
# 240:	learn: 64.7242261	total: 3.54s	remaining: 11.1s
# 241:	learn: 64.6230648	total: 3.55s	remaining: 11.1s
# 242:	learn: 64.5458433	total: 3.56s	remaining: 11.1s
# 243:	learn: 64.5275223	total: 3.57s	remaining: 11s
# 244:	learn: 64.4610084	total: 3.58s	remaining: 11s
# 245:	learn: 64.3957385	total: 3.58s	remaining: 11s
# 246:	learn: 64.3741098	total: 3.59s	remaining: 11s
# 247:	learn: 64.3583287	total: 3.6s	remaining: 10.9s
# 248:	learn: 64.3183060	total: 3.61s	remaining: 10.9s
# 249:	learn: 64.2434988	total: 3.62s	remaining: 10.9s
# 250:	learn: 64.1426284	total: 3.63s	remaining: 10.8s
# 251:	learn: 64.1274842	total: 3.64s	remaining: 10.8s
# 252:	learn: 64.0132385	total: 3.65s	remaining: 10.8s
# 253:	learn: 63.9946131	total: 3.67s	remaining: 10.8s
# 254:	learn: 63.8833677	total: 3.68s	remaining: 10.7s
# 255:	learn: 63.7970289	total: 3.69s	remaining: 10.7s
# 256:	learn: 63.7885216	total: 3.7s	remaining: 10.7s
# 257:	learn: 63.6962742	total: 3.71s	remaining: 10.7s
# 258:	learn: 63.6751332	total: 3.72s	remaining: 10.7s
# 259:	learn: 63.5760193	total: 3.73s	remaining: 10.6s
# 260:	learn: 63.4830980	total: 3.74s	remaining: 10.6s
# 261:	learn: 63.4001925	total: 3.75s	remaining: 10.6s
# 262:	learn: 63.3113066	total: 3.76s	remaining: 10.5s
# 263:	learn: 63.1676993	total: 3.77s	remaining: 10.5s
# 264:	learn: 63.0937256	total: 3.78s	remaining: 10.5s
# 265:	learn: 63.0855032	total: 3.79s	remaining: 10.5s
# 266:	learn: 63.0446116	total: 3.8s	remaining: 10.4s
# 267:	learn: 62.9832079	total: 3.82s	remaining: 10.4s
# 268:	learn: 62.9753425	total: 3.83s	remaining: 10.4s
# 269:	learn: 62.9676916	total: 3.85s	remaining: 10.4s
# 270:	learn: 62.8869358	total: 3.86s	remaining: 10.4s
# 271:	learn: 62.8015876	total: 3.88s	remaining: 10.4s
# 272:	learn: 62.6972260	total: 3.9s	remaining: 10.4s
# 273:	learn: 62.6899335	total: 3.91s	remaining: 10.4s
# 274:	learn: 62.5572342	total: 3.93s	remaining: 10.4s
# 275:	learn: 62.4597074	total: 3.94s	remaining: 10.3s
# 276:	learn: 62.3968834	total: 3.96s	remaining: 10.3s
# 277:	learn: 62.3359367	total: 3.97s	remaining: 10.3s
# 278:	learn: 62.2773822	total: 3.98s	remaining: 10.3s
# 279:	learn: 62.1935745	total: 4s	remaining: 10.3s
# 280:	learn: 62.1495039	total: 4.02s	remaining: 10.3s
# 281:	learn: 62.1368508	total: 4.03s	remaining: 10.3s
# 282:	learn: 62.1300014	total: 4.04s	remaining: 10.2s
# 283:	learn: 62.1232935	total: 4.05s	remaining: 10.2s
# 284:	learn: 62.0465531	total: 4.06s	remaining: 10.2s
# 285:	learn: 61.9920926	total: 4.07s	remaining: 10.2s
# 286:	learn: 61.9326465	total: 4.08s	remaining: 10.1s
# 287:	learn: 61.9261512	total: 4.09s	remaining: 10.1s
# 288:	learn: 61.8367694	total: 4.1s	remaining: 10.1s
# 289:	learn: 61.7883017	total: 4.11s	remaining: 10.1s
# 290:	learn: 61.7816689	total: 4.11s	remaining: 10s
# 291:	learn: 61.7755258	total: 4.12s	remaining: 10s
# 292:	learn: 61.6989807	total: 4.13s	remaining: 9.97s
# 293:	learn: 61.6928019	total: 4.14s	remaining: 9.94s
# 294:	learn: 61.6869681	total: 4.15s	remaining: 9.92s
# 295:	learn: 61.5950885	total: 4.16s	remaining: 9.89s
# 296:	learn: 61.5185634	total: 4.17s	remaining: 9.87s
# 297:	learn: 61.4715331	total: 4.18s	remaining: 9.84s
# 298:	learn: 61.3764440	total: 4.19s	remaining: 9.82s
# 299:	learn: 61.3213202	total: 4.2s	remaining: 9.79s
# 300:	learn: 61.2674817	total: 4.21s	remaining: 9.77s
# 301:	learn: 61.2213510	total: 4.21s	remaining: 9.74s
# 302:	learn: 61.1415891	total: 4.22s	remaining: 9.72s
# 303:	learn: 61.0820560	total: 4.24s	remaining: 9.7s
# 304:	learn: 61.0042481	total: 4.25s	remaining: 9.68s
# 305:	learn: 60.9148057	total: 4.26s	remaining: 9.66s
# 306:	learn: 60.8289001	total: 4.27s	remaining: 9.63s
# 307:	learn: 60.8204349	total: 4.28s	remaining: 9.61s
# 308:	learn: 60.7192381	total: 4.29s	remaining: 9.59s
# 309:	learn: 60.6603322	total: 4.3s	remaining: 9.57s
# 310:	learn: 60.6545975	total: 4.31s	remaining: 9.55s
# 311:	learn: 60.6483416	total: 4.32s	remaining: 9.53s
# 312:	learn: 60.6012741	total: 4.33s	remaining: 9.51s
# 313:	learn: 60.5952655	total: 4.34s	remaining: 9.49s
# 314:	learn: 60.5485040	total: 4.35s	remaining: 9.46s
# 315:	learn: 60.5104650	total: 4.36s	remaining: 9.44s
# 316:	learn: 60.4417904	total: 4.37s	remaining: 9.42s
# 317:	learn: 60.3993022	total: 4.38s	remaining: 9.4s
# 318:	learn: 60.3427879	total: 4.39s	remaining: 9.38s
# 319:	learn: 60.2491444	total: 4.41s	remaining: 9.36s
# 320:	learn: 60.2421532	total: 4.42s	remaining: 9.34s
# 321:	learn: 60.1801022	total: 4.43s	remaining: 9.32s
# 322:	learn: 60.1729206	total: 4.44s	remaining: 9.3s
# 323:	learn: 60.1591293	total: 4.45s	remaining: 9.28s
# 324:	learn: 60.1232603	total: 4.46s	remaining: 9.26s
# 325:	learn: 60.0590922	total: 4.47s	remaining: 9.24s
# 326:	learn: 60.0392356	total: 4.48s	remaining: 9.22s
# 327:	learn: 59.9821029	total: 4.49s	remaining: 9.2s
# 328:	learn: 59.9122600	total: 4.5s	remaining: 9.18s
# 329:	learn: 59.8453012	total: 4.51s	remaining: 9.17s
# 330:	learn: 59.7906420	total: 4.53s	remaining: 9.15s
# 331:	learn: 59.7859671	total: 4.54s	remaining: 9.13s
# 332:	learn: 59.7327031	total: 4.55s	remaining: 9.11s
# 333:	learn: 59.6668279	total: 4.56s	remaining: 9.09s
# 334:	learn: 59.6622923	total: 4.57s	remaining: 9.06s
# 335:	learn: 59.6071787	total: 4.58s	remaining: 9.05s
# 336:	learn: 59.5460455	total: 4.59s	remaining: 9.03s
# 337:	learn: 59.4817598	total: 4.6s	remaining: 9.01s
# 338:	learn: 59.4195832	total: 4.61s	remaining: 8.99s
# 339:	learn: 59.3600366	total: 4.62s	remaining: 8.98s
# 340:	learn: 59.2965650	total: 4.63s	remaining: 8.96s
# 341:	learn: 59.2596510	total: 4.65s	remaining: 8.94s
# 342:	learn: 59.2170620	total: 4.66s	remaining: 8.92s
# 343:	learn: 59.1661379	total: 4.67s	remaining: 8.9s
# 344:	learn: 59.0972258	total: 4.68s	remaining: 8.88s
# 345:	learn: 59.0184040	total: 4.69s	remaining: 8.86s
# 346:	learn: 59.0141287	total: 4.7s	remaining: 8.84s
# 347:	learn: 58.9160576	total: 4.71s	remaining: 8.83s
# 348:	learn: 58.8433545	total: 4.72s	remaining: 8.81s
# 349:	learn: 58.7798021	total: 4.73s	remaining: 8.79s
# 350:	learn: 58.6660213	total: 4.74s	remaining: 8.77s
# 351:	learn: 58.5987577	total: 4.75s	remaining: 8.75s
# 352:	learn: 58.5420787	total: 4.76s	remaining: 8.73s
# 353:	learn: 58.4546943	total: 4.78s	remaining: 8.71s
# 354:	learn: 58.3853190	total: 4.79s	remaining: 8.7s
# 355:	learn: 58.3811721	total: 4.8s	remaining: 8.68s
# 356:	learn: 58.3272849	total: 4.81s	remaining: 8.66s
# 357:	learn: 58.2314077	total: 4.82s	remaining: 8.65s
# 358:	learn: 58.1529920	total: 4.83s	remaining: 8.63s
# 359:	learn: 58.0894649	total: 4.84s	remaining: 8.61s
# 360:	learn: 58.0506772	total: 4.85s	remaining: 8.59s
# 361:	learn: 57.9715343	total: 4.86s	remaining: 8.57s
# 362:	learn: 57.9379908	total: 4.87s	remaining: 8.55s
# 363:	learn: 57.8981982	total: 4.88s	remaining: 8.54s
# 364:	learn: 57.8776434	total: 4.9s	remaining: 8.52s
# 365:	learn: 57.8205204	total: 4.91s	remaining: 8.5s
# 366:	learn: 57.7512862	total: 4.92s	remaining: 8.48s
# 367:	learn: 57.7286293	total: 4.93s	remaining: 8.47s
# 368:	learn: 57.6638894	total: 4.95s	remaining: 8.46s
# 369:	learn: 57.5781219	total: 4.96s	remaining: 8.45s
# 370:	learn: 57.5092597	total: 4.98s	remaining: 8.44s
# 371:	learn: 57.4550981	total: 4.99s	remaining: 8.43s
# 372:	learn: 57.3976040	total: 5.01s	remaining: 8.42s
# 373:	learn: 57.3369882	total: 5.02s	remaining: 8.41s
# 374:	learn: 57.2832612	total: 5.04s	remaining: 8.39s
# 375:	learn: 57.2289059	total: 5.04s	remaining: 8.37s
# 376:	learn: 57.2247859	total: 5.05s	remaining: 8.35s
# 377:	learn: 57.1973148	total: 5.06s	remaining: 8.33s
# 378:	learn: 57.1463001	total: 5.07s	remaining: 8.31s
# 379:	learn: 57.0680315	total: 5.08s	remaining: 8.29s
# 380:	learn: 57.0136475	total: 5.09s	remaining: 8.27s
# 381:	learn: 56.9490992	total: 5.1s	remaining: 8.25s
# 382:	learn: 56.9179252	total: 5.11s	remaining: 8.23s
# 383:	learn: 56.9051505	total: 5.12s	remaining: 8.21s
# 384:	learn: 56.8657793	total: 5.13s	remaining: 8.19s
# 385:	learn: 56.7851373	total: 5.14s	remaining: 8.17s
# 386:	learn: 56.7316709	total: 5.15s	remaining: 8.15s
# 387:	learn: 56.6727960	total: 5.16s	remaining: 8.13s
# 388:	learn: 56.6688325	total: 5.17s	remaining: 8.11s
# 389:	learn: 56.6538461	total: 5.17s	remaining: 8.09s
# 390:	learn: 56.6021328	total: 5.18s	remaining: 8.07s
# 391:	learn: 56.5576509	total: 5.2s	remaining: 8.06s
# 392:	learn: 56.5110955	total: 5.21s	remaining: 8.04s
# 393:	learn: 56.4323679	total: 5.22s	remaining: 8.02s
# 394:	learn: 56.3810871	total: 5.22s	remaining: 8s
# 395:	learn: 56.3214496	total: 5.24s	remaining: 7.99s
# 396:	learn: 56.2759734	total: 5.24s	remaining: 7.97s
# 397:	learn: 56.2713895	total: 5.25s	remaining: 7.95s
# 398:	learn: 56.1873279	total: 5.26s	remaining: 7.93s
# 399:	learn: 56.1837426	total: 5.27s	remaining: 7.91s
# 400:	learn: 56.1800544	total: 5.28s	remaining: 7.89s
# 401:	learn: 56.1427944	total: 5.29s	remaining: 7.88s
# 402:	learn: 56.1203118	total: 5.31s	remaining: 7.86s
# 403:	learn: 56.0764951	total: 5.32s	remaining: 7.84s
# 404:	learn: 56.0360301	total: 5.33s	remaining: 7.83s
# 405:	learn: 55.9631557	total: 5.34s	remaining: 7.81s
# 406:	learn: 55.9326483	total: 5.35s	remaining: 7.79s
# 407:	learn: 55.8613086	total: 5.36s	remaining: 7.77s
# 408:	learn: 55.7841127	total: 5.37s	remaining: 7.75s
# 409:	learn: 55.7174658	total: 5.38s	remaining: 7.74s
# 410:	learn: 55.6692753	total: 5.39s	remaining: 7.72s
# 411:	learn: 55.6093144	total: 5.4s	remaining: 7.71s
# 412:	learn: 55.5604095	total: 5.41s	remaining: 7.69s
# 413:	learn: 55.5461847	total: 5.42s	remaining: 7.68s
# 414:	learn: 55.5413472	total: 5.43s	remaining: 7.66s
# 415:	learn: 55.5211371	total: 5.45s	remaining: 7.64s
# 416:	learn: 55.4454088	total: 5.46s	remaining: 7.63s
# 417:	learn: 55.4013399	total: 5.48s	remaining: 7.62s
# 418:	learn: 55.3827503	total: 5.49s	remaining: 7.61s
# 419:	learn: 55.3633960	total: 5.5s	remaining: 7.59s
# 420:	learn: 55.3307181	total: 5.51s	remaining: 7.58s
# 421:	learn: 55.2714605	total: 5.52s	remaining: 7.56s
# 422:	learn: 55.2161116	total: 5.53s	remaining: 7.55s
# 423:	learn: 55.1052513	total: 5.54s	remaining: 7.53s
# 424:	learn: 55.0399333	total: 5.55s	remaining: 7.51s
# 425:	learn: 54.9921113	total: 5.56s	remaining: 7.5s
# 426:	learn: 54.9884528	total: 5.57s	remaining: 7.48s
# 427:	learn: 54.9789566	total: 5.58s	remaining: 7.46s
# 428:	learn: 54.9255591	total: 5.59s	remaining: 7.45s
# 429:	learn: 54.8495328	total: 5.61s	remaining: 7.43s
# 430:	learn: 54.7988332	total: 5.62s	remaining: 7.41s
# 431:	learn: 54.7373716	total: 5.63s	remaining: 7.4s
# 432:	learn: 54.6865477	total: 5.64s	remaining: 7.38s
# 433:	learn: 54.6273532	total: 5.65s	remaining: 7.37s
# 434:	learn: 54.5897999	total: 5.66s	remaining: 7.35s
# 435:	learn: 54.5557156	total: 5.67s	remaining: 7.34s
# 436:	learn: 54.5523531	total: 5.68s	remaining: 7.32s
# 437:	learn: 54.5419988	total: 5.69s	remaining: 7.3s
# 438:	learn: 54.4979013	total: 5.7s	remaining: 7.29s
# 439:	learn: 54.4203348	total: 5.71s	remaining: 7.27s
# 440:	learn: 54.3680736	total: 5.72s	remaining: 7.25s
# 441:	learn: 54.3319126	total: 5.73s	remaining: 7.23s
# 442:	learn: 54.2850435	total: 5.74s	remaining: 7.21s
# 443:	learn: 54.2815275	total: 5.75s	remaining: 7.2s
# 444:	learn: 54.2162832	total: 5.76s	remaining: 7.18s
# 445:	learn: 54.1748748	total: 5.77s	remaining: 7.16s
# 446:	learn: 54.1370372	total: 5.78s	remaining: 7.15s
# 447:	learn: 54.0901427	total: 5.79s	remaining: 7.13s
# 448:	learn: 54.0870711	total: 5.79s	remaining: 7.11s
# 449:	learn: 54.0531462	total: 5.8s	remaining: 7.09s
# 450:	learn: 54.0187842	total: 5.81s	remaining: 7.08s
# 451:	learn: 53.9785229	total: 5.82s	remaining: 7.06s
# 452:	learn: 53.9404263	total: 5.83s	remaining: 7.04s
# 453:	learn: 53.9374322	total: 5.84s	remaining: 7.03s
# 454:	learn: 53.9159434	total: 5.85s	remaining: 7.01s
# 455:	learn: 53.8882569	total: 5.86s	remaining: 6.99s
# 456:	learn: 53.8703987	total: 5.87s	remaining: 6.97s
# 457:	learn: 53.8255555	total: 5.88s	remaining: 6.96s
# 458:	learn: 53.7823234	total: 5.89s	remaining: 6.94s
# 459:	learn: 53.7131333	total: 5.9s	remaining: 6.92s
# 460:	learn: 53.6520488	total: 5.91s	remaining: 6.91s
# 461:	learn: 53.5954921	total: 5.92s	remaining: 6.9s
# 462:	learn: 53.5007990	total: 5.93s	remaining: 6.88s
# 463:	learn: 53.4623082	total: 5.94s	remaining: 6.87s
# 464:	learn: 53.4322631	total: 5.96s	remaining: 6.85s
# 465:	learn: 53.3956511	total: 5.97s	remaining: 6.84s
# 466:	learn: 53.3045651	total: 5.98s	remaining: 6.82s
# 467:	learn: 53.2896086	total: 5.99s	remaining: 6.81s
# 468:	learn: 53.2312724	total: 6s	remaining: 6.79s
# 469:	learn: 53.2024819	total: 6.01s	remaining: 6.78s
# 470:	learn: 53.1440713	total: 6.02s	remaining: 6.76s
# 471:	learn: 53.1171292	total: 6.03s	remaining: 6.74s
# 472:	learn: 53.0877924	total: 6.04s	remaining: 6.73s
# 473:	learn: 53.0092627	total: 6.05s	remaining: 6.71s
# 474:	learn: 53.0060119	total: 6.06s	remaining: 6.7s
# 475:	learn: 52.9487040	total: 6.07s	remaining: 6.68s
# 476:	learn: 52.8879628	total: 6.08s	remaining: 6.66s
# 477:	learn: 52.8372035	total: 6.09s	remaining: 6.65s
# 478:	learn: 52.8009423	total: 6.1s	remaining: 6.64s
# 479:	learn: 52.7688140	total: 6.11s	remaining: 6.62s
# 480:	learn: 52.7277197	total: 6.12s	remaining: 6.61s
# 481:	learn: 52.7245741	total: 6.13s	remaining: 6.59s
# 482:	learn: 52.6718209	total: 6.15s	remaining: 6.58s
# 483:	learn: 52.6164442	total: 6.16s	remaining: 6.57s
# 484:	learn: 52.5788064	total: 6.17s	remaining: 6.55s
# 485:	learn: 52.5553052	total: 6.18s	remaining: 6.54s
# 486:	learn: 52.4899699	total: 6.19s	remaining: 6.52s
# 487:	learn: 52.4511648	total: 6.2s	remaining: 6.51s
# 488:	learn: 52.4042265	total: 6.21s	remaining: 6.49s
# 489:	learn: 52.3149315	total: 6.22s	remaining: 6.48s
# 490:	learn: 52.2878269	total: 6.24s	remaining: 6.47s
# 491:	learn: 52.2338970	total: 6.25s	remaining: 6.46s
# 492:	learn: 52.1867363	total: 6.26s	remaining: 6.44s
# 493:	learn: 52.1831493	total: 6.27s	remaining: 6.43s
# 494:	learn: 52.1511369	total: 6.28s	remaining: 6.41s
# 495:	learn: 52.1097119	total: 6.29s	remaining: 6.4s
# 496:	learn: 52.0456498	total: 6.3s	remaining: 6.38s
# 497:	learn: 52.0358834	total: 6.31s	remaining: 6.36s
# 498:	learn: 52.0330061	total: 6.32s	remaining: 6.35s
# 499:	learn: 52.0071513	total: 6.33s	remaining: 6.33s
# 500:	learn: 51.9519203	total: 6.34s	remaining: 6.32s
# 501:	learn: 51.9035672	total: 6.35s	remaining: 6.3s
# 502:	learn: 51.8665621	total: 6.36s	remaining: 6.29s
# 503:	learn: 51.7919668	total: 6.37s	remaining: 6.27s
# 504:	learn: 51.7542161	total: 6.38s	remaining: 6.25s
# 505:	learn: 51.6760955	total: 6.39s	remaining: 6.24s
# 506:	learn: 51.6555002	total: 6.4s	remaining: 6.22s
# 507:	learn: 51.6051079	total: 6.41s	remaining: 6.21s
# 508:	learn: 51.5934111	total: 6.42s	remaining: 6.19s
# 509:	learn: 51.5595167	total: 6.43s	remaining: 6.18s
# 510:	learn: 51.5255115	total: 6.44s	remaining: 6.16s
# 511:	learn: 51.4961060	total: 6.45s	remaining: 6.15s
# 512:	learn: 51.4725036	total: 6.46s	remaining: 6.13s
# 513:	learn: 51.4102056	total: 6.47s	remaining: 6.12s
# 514:	learn: 51.3710964	total: 6.48s	remaining: 6.1s
# 515:	learn: 51.3512584	total: 6.49s	remaining: 6.09s
# 516:	learn: 51.3059376	total: 6.5s	remaining: 6.07s
# 517:	learn: 51.2520306	total: 6.51s	remaining: 6.06s
# 518:	learn: 51.2272900	total: 6.52s	remaining: 6.05s
# 519:	learn: 51.2142480	total: 6.54s	remaining: 6.03s
# 520:	learn: 51.1845223	total: 6.55s	remaining: 6.02s
# 521:	learn: 51.1453674	total: 6.56s	remaining: 6s
# 522:	learn: 51.1158268	total: 6.57s	remaining: 5.99s
# 523:	learn: 51.0573403	total: 6.58s	remaining: 5.97s
# 524:	learn: 51.0040573	total: 6.58s	remaining: 5.96s
# 525:	learn: 50.9539348	total: 6.6s	remaining: 5.94s
# 526:	learn: 50.9511501	total: 6.61s	remaining: 5.93s
# 527:	learn: 50.9066196	total: 6.62s	remaining: 5.92s
# 528:	learn: 50.8696025	total: 6.63s	remaining: 5.9s
# 529:	learn: 50.8615880	total: 6.64s	remaining: 5.89s
# 530:	learn: 50.8123519	total: 6.65s	remaining: 5.87s
# 531:	learn: 50.7435368	total: 6.66s	remaining: 5.86s
# 532:	learn: 50.6921488	total: 6.67s	remaining: 5.84s
# 533:	learn: 50.6562194	total: 6.68s	remaining: 5.83s
# 534:	learn: 50.5851977	total: 6.69s	remaining: 5.82s
# 535:	learn: 50.5750631	total: 6.7s	remaining: 5.8s
# 536:	learn: 50.5210954	total: 6.71s	remaining: 5.78s
# 537:	learn: 50.5072773	total: 6.72s	remaining: 5.77s
# 538:	learn: 50.4666344	total: 6.74s	remaining: 5.76s
# 539:	learn: 50.4318296	total: 6.75s	remaining: 5.75s
# 540:	learn: 50.3909286	total: 6.76s	remaining: 5.74s
# 541:	learn: 50.3831234	total: 6.79s	remaining: 5.73s
# 542:	learn: 50.3544463	total: 6.81s	remaining: 5.73s
# 543:	learn: 50.3183268	total: 6.84s	remaining: 5.73s
# 544:	learn: 50.2632527	total: 6.87s	remaining: 5.73s
# 545:	learn: 50.2312051	total: 6.88s	remaining: 5.72s
# 546:	learn: 50.1854347	total: 6.9s	remaining: 5.71s
# 547:	learn: 50.1627669	total: 6.91s	remaining: 5.7s
# 548:	learn: 50.1160007	total: 6.92s	remaining: 5.69s
# 549:	learn: 50.0972230	total: 6.93s	remaining: 5.67s
# 550:	learn: 50.0309038	total: 6.95s	remaining: 5.66s
# 551:	learn: 49.9738931	total: 6.96s	remaining: 5.65s
# 552:	learn: 49.9604863	total: 6.97s	remaining: 5.63s
# 553:	learn: 49.9211800	total: 6.99s	remaining: 5.62s
# 554:	learn: 49.8673229	total: 7s	remaining: 5.61s
# 555:	learn: 49.8408101	total: 7.01s	remaining: 5.6s
# 556:	learn: 49.8038492	total: 7.02s	remaining: 5.58s
# 557:	learn: 49.7513406	total: 7.03s	remaining: 5.57s
# 558:	learn: 49.7321323	total: 7.04s	remaining: 5.56s
# 559:	learn: 49.7043214	total: 7.06s	remaining: 5.55s
# 560:	learn: 49.6970358	total: 7.07s	remaining: 5.53s
# 561:	learn: 49.6549519	total: 7.08s	remaining: 5.52s
# 562:	learn: 49.6523249	total: 7.1s	remaining: 5.51s
# 563:	learn: 49.6233127	total: 7.11s	remaining: 5.5s
# 564:	learn: 49.5964180	total: 7.12s	remaining: 5.48s
# 565:	learn: 49.5590887	total: 7.13s	remaining: 5.47s
# 566:	learn: 49.5416655	total: 7.15s	remaining: 5.46s
# 567:	learn: 49.5045016	total: 7.16s	remaining: 5.45s
# 568:	learn: 49.4711002	total: 7.17s	remaining: 5.43s
# 569:	learn: 49.4612032	total: 7.18s	remaining: 5.42s
# 570:	learn: 49.4156137	total: 7.19s	remaining: 5.4s
# 571:	learn: 49.3684786	total: 7.21s	remaining: 5.39s
# 572:	learn: 49.3277907	total: 7.22s	remaining: 5.38s
# 573:	learn: 49.2995480	total: 7.23s	remaining: 5.37s
# 574:	learn: 49.2052190	total: 7.24s	remaining: 5.35s
# 575:	learn: 49.1663983	total: 7.25s	remaining: 5.34s
# 576:	learn: 49.1309780	total: 7.27s	remaining: 5.33s
# 577:	learn: 49.1285159	total: 7.28s	remaining: 5.31s
# 578:	learn: 49.1260168	total: 7.29s	remaining: 5.3s
# 579:	learn: 49.0802471	total: 7.31s	remaining: 5.29s
# 580:	learn: 49.0482071	total: 7.34s	remaining: 5.29s
# 581:	learn: 49.0458434	total: 7.36s	remaining: 5.29s
# 582:	learn: 48.9848061	total: 7.38s	remaining: 5.28s
# 583:	learn: 48.9252010	total: 7.4s	remaining: 5.27s
# 584:	learn: 48.8914011	total: 7.42s	remaining: 5.26s
# 585:	learn: 48.8721542	total: 7.43s	remaining: 5.25s
# 586:	learn: 48.8577791	total: 7.44s	remaining: 5.24s
# 587:	learn: 48.7959929	total: 7.45s	remaining: 5.22s
# 588:	learn: 48.7654118	total: 7.46s	remaining: 5.21s
# 589:	learn: 48.7599669	total: 7.48s	remaining: 5.2s
# 590:	learn: 48.7531043	total: 7.49s	remaining: 5.18s
# 591:	learn: 48.7373538	total: 7.5s	remaining: 5.17s
# 592:	learn: 48.6953171	total: 7.51s	remaining: 5.16s
# 593:	learn: 48.6830637	total: 7.53s	remaining: 5.14s
# 594:	learn: 48.6287199	total: 7.54s	remaining: 5.13s
# 595:	learn: 48.6086401	total: 7.55s	remaining: 5.12s
# 596:	learn: 48.5717043	total: 7.55s	remaining: 5.1s
# 597:	learn: 48.5649861	total: 7.56s	remaining: 5.08s
# 598:	learn: 48.5316235	total: 7.57s	remaining: 5.07s
# 599:	learn: 48.5122385	total: 7.58s	remaining: 5.05s
# 600:	learn: 48.4620954	total: 7.59s	remaining: 5.04s
# 601:	learn: 48.4175423	total: 7.61s	remaining: 5.03s
# 602:	learn: 48.3522147	total: 7.61s	remaining: 5.01s
# 603:	learn: 48.3149942	total: 7.62s	remaining: 5s
# 604:	learn: 48.3011283	total: 7.64s	remaining: 4.99s
# 605:	learn: 48.2456172	total: 7.65s	remaining: 4.97s
# 606:	learn: 48.2264244	total: 7.67s	remaining: 4.97s
# 607:	learn: 48.2014673	total: 7.69s	remaining: 4.96s
# 608:	learn: 48.1610633	total: 7.71s	remaining: 4.95s
# 609:	learn: 48.1186753	total: 7.73s	remaining: 4.94s
# 610:	learn: 48.1122558	total: 7.74s	remaining: 4.93s
# 611:	learn: 48.0840715	total: 7.75s	remaining: 4.92s
# 612:	learn: 48.0477793	total: 7.77s	remaining: 4.9s
# 613:	learn: 47.9753764	total: 7.78s	remaining: 4.89s
# 614:	learn: 47.9516095	total: 7.79s	remaining: 4.87s
# 615:	learn: 47.9272223	total: 7.79s	remaining: 4.86s
# 616:	learn: 47.9043792	total: 7.8s	remaining: 4.84s
# 617:	learn: 47.8884809	total: 7.81s	remaining: 4.83s
# 618:	learn: 47.8863947	total: 7.82s	remaining: 4.81s
# 619:	learn: 47.8236519	total: 7.83s	remaining: 4.8s
# 620:	learn: 47.8197547	total: 7.84s	remaining: 4.79s
# 621:	learn: 47.7639472	total: 7.85s	remaining: 4.77s
# 622:	learn: 47.7510845	total: 7.86s	remaining: 4.76s
# 623:	learn: 47.7241330	total: 7.87s	remaining: 4.74s
# 624:	learn: 47.6841106	total: 7.88s	remaining: 4.73s
# 625:	learn: 47.6495825	total: 7.89s	remaining: 4.71s
# 626:	learn: 47.6218623	total: 7.9s	remaining: 4.7s
# 627:	learn: 47.5807485	total: 7.91s	remaining: 4.68s
# 628:	learn: 47.5678340	total: 7.91s	remaining: 4.67s
# 629:	learn: 47.5622218	total: 7.92s	remaining: 4.65s
# 630:	learn: 47.5152561	total: 7.93s	remaining: 4.64s
# 631:	learn: 47.4450154	total: 7.94s	remaining: 4.63s
# 632:	learn: 47.4338121	total: 7.95s	remaining: 4.61s
# 633:	learn: 47.3855123	total: 7.96s	remaining: 4.6s
# 634:	learn: 47.3395331	total: 7.97s	remaining: 4.58s
# 635:	learn: 47.2956836	total: 7.98s	remaining: 4.57s
# 636:	learn: 47.2496141	total: 7.99s	remaining: 4.55s
# 637:	learn: 47.2362270	total: 8s	remaining: 4.54s
# 638:	learn: 47.1865545	total: 8.01s	remaining: 4.53s
# 639:	learn: 47.1753725	total: 8.02s	remaining: 4.51s
# 640:	learn: 47.1464392	total: 8.03s	remaining: 4.5s
# 641:	learn: 47.1349629	total: 8.04s	remaining: 4.48s
# 642:	learn: 47.1015044	total: 8.05s	remaining: 4.47s
# 643:	learn: 47.0907237	total: 8.06s	remaining: 4.45s
# 644:	learn: 47.0686104	total: 8.07s	remaining: 4.44s
# 645:	learn: 47.0170876	total: 8.07s	remaining: 4.42s
# 646:	learn: 47.0071615	total: 8.08s	remaining: 4.41s
# 647:	learn: 46.9775868	total: 8.09s	remaining: 4.4s
# 648:	learn: 46.9388112	total: 8.1s	remaining: 4.38s
# 649:	learn: 46.9150878	total: 8.12s	remaining: 4.37s
# 650:	learn: 46.8935106	total: 8.12s	remaining: 4.36s
# 651:	learn: 46.8684413	total: 8.13s	remaining: 4.34s
# 652:	learn: 46.8337312	total: 8.14s	remaining: 4.33s
# 653:	learn: 46.8117017	total: 8.15s	remaining: 4.31s
# 654:	learn: 46.8097132	total: 8.16s	remaining: 4.3s
# 655:	learn: 46.8078330	total: 8.18s	remaining: 4.29s
# 656:	learn: 46.8013188	total: 8.19s	remaining: 4.28s
# 657:	learn: 46.7709458	total: 8.21s	remaining: 4.27s
# 658:	learn: 46.7126420	total: 8.22s	remaining: 4.26s
# 659:	learn: 46.7080603	total: 8.24s	remaining: 4.25s
# 660:	learn: 46.6799076	total: 8.26s	remaining: 4.24s
# 661:	learn: 46.6697504	total: 8.28s	remaining: 4.23s
# 662:	learn: 46.6389672	total: 8.3s	remaining: 4.22s
# 663:	learn: 46.5878324	total: 8.32s	remaining: 4.21s
# 664:	learn: 46.5467702	total: 8.34s	remaining: 4.2s
# 665:	learn: 46.5040366	total: 8.36s	remaining: 4.19s
# 666:	learn: 46.4611865	total: 8.37s	remaining: 4.18s
# 667:	learn: 46.4394712	total: 8.39s	remaining: 4.17s
# 668:	learn: 46.4055631	total: 8.41s	remaining: 4.16s
# 669:	learn: 46.3923436	total: 8.42s	remaining: 4.14s
# 670:	learn: 46.3730636	total: 8.43s	remaining: 4.13s
# 671:	learn: 46.3479745	total: 8.44s	remaining: 4.12s
# 672:	learn: 46.3118714	total: 8.45s	remaining: 4.11s
# 673:	learn: 46.2597989	total: 8.46s	remaining: 4.09s
# 674:	learn: 46.2238205	total: 8.48s	remaining: 4.08s
# 675:	learn: 46.1853425	total: 8.49s	remaining: 4.07s
# 676:	learn: 46.1658143	total: 8.5s	remaining: 4.06s
# 677:	learn: 46.1606226	total: 8.52s	remaining: 4.04s
# 678:	learn: 46.1494234	total: 8.53s	remaining: 4.03s
# 679:	learn: 46.0992673	total: 8.54s	remaining: 4.02s
# 680:	learn: 46.0439223	total: 8.55s	remaining: 4.01s
# 681:	learn: 46.0146187	total: 8.57s	remaining: 3.99s
# 682:	learn: 45.9835878	total: 8.58s	remaining: 3.98s
# 683:	learn: 45.9769280	total: 8.59s	remaining: 3.97s
# 684:	learn: 45.9269667	total: 8.6s	remaining: 3.95s
# 685:	learn: 45.9128755	total: 8.61s	remaining: 3.94s
# 686:	learn: 45.8758073	total: 8.63s	remaining: 3.93s
# 687:	learn: 45.8397535	total: 8.64s	remaining: 3.92s
# 688:	learn: 45.7960256	total: 8.66s	remaining: 3.91s
# 689:	learn: 45.7578170	total: 8.68s	remaining: 3.9s
# 690:	learn: 45.7283992	total: 8.69s	remaining: 3.88s
# 691:	learn: 45.6909559	total: 8.7s	remaining: 3.87s
# 692:	learn: 45.6781815	total: 8.72s	remaining: 3.86s
# 693:	learn: 45.6559043	total: 8.74s	remaining: 3.85s
# 694:	learn: 45.6073780	total: 8.76s	remaining: 3.84s
# 695:	learn: 45.6057953	total: 8.77s	remaining: 3.83s
# 696:	learn: 45.5718883	total: 8.79s	remaining: 3.82s
# 697:	learn: 45.5642113	total: 8.8s	remaining: 3.81s
# 698:	learn: 45.5505236	total: 8.81s	remaining: 3.79s
# 699:	learn: 45.5276893	total: 8.83s	remaining: 3.78s
# 700:	learn: 45.5010937	total: 8.84s	remaining: 3.77s
# 701:	learn: 45.4904850	total: 8.85s	remaining: 3.75s
# 702:	learn: 45.4747719	total: 8.86s	remaining: 3.74s
# 703:	learn: 45.4539082	total: 8.87s	remaining: 3.73s
# 704:	learn: 45.4162446	total: 8.88s	remaining: 3.71s
# 705:	learn: 45.3713212	total: 8.89s	remaining: 3.7s
# 706:	learn: 45.3533772	total: 8.9s	remaining: 3.69s
# 707:	learn: 45.3290314	total: 8.91s	remaining: 3.67s
# 708:	learn: 45.2830984	total: 8.92s	remaining: 3.66s
# 709:	learn: 45.2426005	total: 8.94s	remaining: 3.65s
# 710:	learn: 45.2269013	total: 8.95s	remaining: 3.64s
# 711:	learn: 45.1789328	total: 8.96s	remaining: 3.62s
# 712:	learn: 45.1352088	total: 8.97s	remaining: 3.61s
# 713:	learn: 45.1330349	total: 8.98s	remaining: 3.6s
# 714:	learn: 45.0887802	total: 8.99s	remaining: 3.58s
# 715:	learn: 45.0356978	total: 9s	remaining: 3.57s
# 716:	learn: 45.0242351	total: 9.01s	remaining: 3.56s
# 717:	learn: 45.0140909	total: 9.03s	remaining: 3.55s
# 718:	learn: 45.0053736	total: 9.04s	remaining: 3.53s
# 719:	learn: 44.9598618	total: 9.06s	remaining: 3.52s
# 720:	learn: 44.9139820	total: 9.07s	remaining: 3.51s
# 721:	learn: 44.8793474	total: 9.08s	remaining: 3.5s
# 722:	learn: 44.8368970	total: 9.09s	remaining: 3.48s
# 723:	learn: 44.8126103	total: 9.11s	remaining: 3.47s
# 724:	learn: 44.7775483	total: 9.12s	remaining: 3.46s
# 725:	learn: 44.7697491	total: 9.13s	remaining: 3.45s
# 726:	learn: 44.7368810	total: 9.14s	remaining: 3.43s
# 727:	learn: 44.7239919	total: 9.15s	remaining: 3.42s
# 728:	learn: 44.7127238	total: 9.16s	remaining: 3.4s
# 729:	learn: 44.6625258	total: 9.17s	remaining: 3.39s
# 730:	learn: 44.6469067	total: 9.18s	remaining: 3.38s
# 731:	learn: 44.6439253	total: 9.19s	remaining: 3.37s
# 732:	learn: 44.6375857	total: 9.2s	remaining: 3.35s
# 733:	learn: 44.6062169	total: 9.21s	remaining: 3.34s
# 734:	learn: 44.5949281	total: 9.22s	remaining: 3.33s
# 735:	learn: 44.5558248	total: 9.23s	remaining: 3.31s
# 736:	learn: 44.5451681	total: 9.25s	remaining: 3.3s
# 737:	learn: 44.4814858	total: 9.26s	remaining: 3.29s
# 738:	learn: 44.4776957	total: 9.27s	remaining: 3.27s
# 739:	learn: 44.4417232	total: 9.28s	remaining: 3.26s
# 740:	learn: 44.4021820	total: 9.29s	remaining: 3.25s
# 741:	learn: 44.3996864	total: 9.3s	remaining: 3.23s
# 742:	learn: 44.3757535	total: 9.31s	remaining: 3.22s
# 743:	learn: 44.3103659	total: 9.32s	remaining: 3.21s
# 744:	learn: 44.2923127	total: 9.34s	remaining: 3.19s
# 745:	learn: 44.2579523	total: 9.35s	remaining: 3.18s
# 746:	learn: 44.2377043	total: 9.36s	remaining: 3.17s
# 747:	learn: 44.2239133	total: 9.37s	remaining: 3.15s
# 748:	learn: 44.2221926	total: 9.38s	remaining: 3.14s
# 749:	learn: 44.1884650	total: 9.39s	remaining: 3.13s
# 750:	learn: 44.1566708	total: 9.4s	remaining: 3.12s
# 751:	learn: 44.1338449	total: 9.41s	remaining: 3.1s
# 752:	learn: 44.1038986	total: 9.43s	remaining: 3.09s
# 753:	learn: 44.0664704	total: 9.44s	remaining: 3.08s
# 754:	learn: 44.0421380	total: 9.46s	remaining: 3.07s
# 755:	learn: 44.0125393	total: 9.48s	remaining: 3.06s
# 756:	learn: 44.0002409	total: 9.49s	remaining: 3.05s
# 757:	learn: 43.9946792	total: 9.51s	remaining: 3.04s
# 758:	learn: 43.9714700	total: 9.52s	remaining: 3.02s
# 759:	learn: 43.9383257	total: 9.54s	remaining: 3.01s
# 760:	learn: 43.9261239	total: 9.55s	remaining: 3s
# 761:	learn: 43.8816709	total: 9.57s	remaining: 2.99s
# 762:	learn: 43.8439196	total: 9.58s	remaining: 2.98s
# 763:	learn: 43.8422562	total: 9.6s	remaining: 2.96s
# 764:	learn: 43.8232578	total: 9.61s	remaining: 2.95s
# 765:	learn: 43.7427335	total: 9.62s	remaining: 2.94s
# 766:	learn: 43.7290538	total: 9.64s	remaining: 2.93s
# 767:	learn: 43.6989340	total: 9.65s	remaining: 2.91s
# 768:	learn: 43.6685064	total: 9.66s	remaining: 2.9s
# 769:	learn: 43.6486333	total: 9.68s	remaining: 2.89s
# 770:	learn: 43.6097718	total: 9.7s	remaining: 2.88s
# 771:	learn: 43.5683212	total: 9.72s	remaining: 2.87s
# 772:	learn: 43.5267493	total: 9.73s	remaining: 2.86s
# 773:	learn: 43.5051593	total: 9.74s	remaining: 2.85s
# 774:	learn: 43.4856299	total: 9.76s	remaining: 2.83s
# 775:	learn: 43.4512651	total: 9.77s	remaining: 2.82s
# 776:	learn: 43.4319727	total: 9.77s	remaining: 2.81s
# 777:	learn: 43.4054808	total: 9.78s	remaining: 2.79s
# 778:	learn: 43.3942103	total: 9.79s	remaining: 2.78s
# 779:	learn: 43.3708727	total: 9.8s	remaining: 2.76s
# 780:	learn: 43.3615061	total: 9.81s	remaining: 2.75s
# 781:	learn: 43.3285833	total: 9.82s	remaining: 2.74s
# 782:	learn: 43.3158759	total: 9.83s	remaining: 2.72s
# 783:	learn: 43.2790008	total: 9.84s	remaining: 2.71s
# 784:	learn: 43.2516416	total: 9.85s	remaining: 2.7s
# 785:	learn: 43.2233283	total: 9.86s	remaining: 2.68s
# 786:	learn: 43.2147739	total: 9.86s	remaining: 2.67s
# 787:	learn: 43.2013401	total: 9.88s	remaining: 2.66s
# 788:	learn: 43.1964473	total: 9.89s	remaining: 2.64s
# 789:	learn: 43.1898038	total: 9.89s	remaining: 2.63s
# 790:	learn: 43.1580695	total: 9.9s	remaining: 2.62s
# 791:	learn: 43.1371570	total: 9.91s	remaining: 2.6s
# 792:	learn: 43.1242470	total: 9.92s	remaining: 2.59s
# 793:	learn: 43.1029456	total: 9.93s	remaining: 2.58s
# 794:	learn: 43.1006461	total: 9.94s	remaining: 2.56s
# 795:	learn: 43.0962789	total: 9.95s	remaining: 2.55s
# 796:	learn: 43.0580214	total: 9.96s	remaining: 2.54s
# 797:	learn: 43.0436174	total: 9.97s	remaining: 2.52s
# 798:	learn: 43.0414274	total: 9.98s	remaining: 2.51s
# 799:	learn: 43.0094618	total: 9.99s	remaining: 2.5s
# 800:	learn: 42.9527334	total: 10s	remaining: 2.48s
# 801:	learn: 42.9367073	total: 10s	remaining: 2.47s
# 802:	learn: 42.8816614	total: 10s	remaining: 2.46s
# 803:	learn: 42.8454955	total: 10s	remaining: 2.44s
# 804:	learn: 42.8360088	total: 10s	remaining: 2.43s
# 805:	learn: 42.8071772	total: 10s	remaining: 2.42s
# 806:	learn: 42.7783453	total: 10.1s	remaining: 2.4s
# 807:	learn: 42.7502792	total: 10.1s	remaining: 2.39s
# 808:	learn: 42.7178382	total: 10.1s	remaining: 2.38s
# 809:	learn: 42.6745082	total: 10.1s	remaining: 2.37s
# 810:	learn: 42.6488097	total: 10.1s	remaining: 2.35s
# 811:	learn: 42.6374062	total: 10.1s	remaining: 2.34s
# 812:	learn: 42.5944999	total: 10.1s	remaining: 2.33s
# 813:	learn: 42.5700904	total: 10.1s	remaining: 2.31s
# 814:	learn: 42.5682511	total: 10.1s	remaining: 2.3s
# 815:	learn: 42.5450633	total: 10.1s	remaining: 2.29s
# 816:	learn: 42.5265069	total: 10.2s	remaining: 2.27s
# 817:	learn: 42.4721140	total: 10.2s	remaining: 2.26s
# 818:	learn: 42.4439267	total: 10.2s	remaining: 2.25s
# 819:	learn: 42.4336233	total: 10.2s	remaining: 2.24s
# 820:	learn: 42.3979473	total: 10.2s	remaining: 2.22s
# 821:	learn: 42.3773654	total: 10.2s	remaining: 2.21s
# 822:	learn: 42.3425404	total: 10.2s	remaining: 2.2s
# 823:	learn: 42.3314466	total: 10.2s	remaining: 2.19s
# 824:	learn: 42.3137475	total: 10.3s	remaining: 2.18s
# 825:	learn: 42.2864235	total: 10.3s	remaining: 2.17s
# 826:	learn: 42.2552840	total: 10.3s	remaining: 2.15s
# 827:	learn: 42.2099764	total: 10.3s	remaining: 2.14s
# 828:	learn: 42.1923539	total: 10.3s	remaining: 2.13s
# 829:	learn: 42.1352486	total: 10.3s	remaining: 2.12s
# 830:	learn: 42.0963710	total: 10.3s	remaining: 2.1s
# 831:	learn: 42.0716532	total: 10.4s	remaining: 2.09s
# 832:	learn: 42.0307214	total: 10.4s	remaining: 2.08s
# 833:	learn: 42.0293163	total: 10.4s	remaining: 2.07s
# 834:	learn: 42.0278998	total: 10.4s	remaining: 2.06s
# 835:	learn: 41.9898327	total: 10.4s	remaining: 2.04s
# 836:	learn: 41.9801746	total: 10.4s	remaining: 2.03s
# 837:	learn: 41.9784467	total: 10.4s	remaining: 2.02s
# 838:	learn: 41.9537528	total: 10.5s	remaining: 2.01s
# 839:	learn: 41.9392977	total: 10.5s	remaining: 2s
# 840:	learn: 41.9086387	total: 10.5s	remaining: 1.98s
# 841:	learn: 41.8770636	total: 10.5s	remaining: 1.97s
# 842:	learn: 41.8629651	total: 10.5s	remaining: 1.96s
# 843:	learn: 41.8541906	total: 10.5s	remaining: 1.94s
# 844:	learn: 41.8521851	total: 10.5s	remaining: 1.93s
# 845:	learn: 41.8296187	total: 10.5s	remaining: 1.92s
# 846:	learn: 41.8283346	total: 10.6s	remaining: 1.91s
# 847:	learn: 41.7972348	total: 10.6s	remaining: 1.89s
# 848:	learn: 41.7876152	total: 10.6s	remaining: 1.88s
# 849:	learn: 41.7360562	total: 10.6s	remaining: 1.87s
# 850:	learn: 41.7123966	total: 10.6s	remaining: 1.86s
# 851:	learn: 41.6961834	total: 10.6s	remaining: 1.85s
# 852:	learn: 41.6674670	total: 10.6s	remaining: 1.83s
# 853:	learn: 41.6112022	total: 10.7s	remaining: 1.82s
# 854:	learn: 41.5783637	total: 10.7s	remaining: 1.81s
# 855:	learn: 41.5400902	total: 10.7s	remaining: 1.8s
# 856:	learn: 41.5311406	total: 10.7s	remaining: 1.78s
# 857:	learn: 41.5061523	total: 10.7s	remaining: 1.77s
# 858:	learn: 41.4794228	total: 10.7s	remaining: 1.76s
# 859:	learn: 41.4632146	total: 10.7s	remaining: 1.75s
# 860:	learn: 41.4117066	total: 10.7s	remaining: 1.73s
# 861:	learn: 41.4101192	total: 10.8s	remaining: 1.72s
# 862:	learn: 41.3918473	total: 10.8s	remaining: 1.71s
# 863:	learn: 41.3451181	total: 10.8s	remaining: 1.7s
# 864:	learn: 41.3157525	total: 10.8s	remaining: 1.68s
# 865:	learn: 41.2942352	total: 10.8s	remaining: 1.67s
# 866:	learn: 41.2762464	total: 10.8s	remaining: 1.66s
# 867:	learn: 41.2153901	total: 10.8s	remaining: 1.64s
# 868:	learn: 41.1923211	total: 10.8s	remaining: 1.63s
# 869:	learn: 41.1683001	total: 10.8s	remaining: 1.62s
# 870:	learn: 41.1358869	total: 10.8s	remaining: 1.6s
# 871:	learn: 41.1343826	total: 10.8s	remaining: 1.59s
# 872:	learn: 41.1080971	total: 10.9s	remaining: 1.58s
# 873:	learn: 41.0923371	total: 10.9s	remaining: 1.57s
# 874:	learn: 41.0862822	total: 10.9s	remaining: 1.55s
# 875:	learn: 41.0707424	total: 10.9s	remaining: 1.54s
# 876:	learn: 41.0413736	total: 10.9s	remaining: 1.53s
# 877:	learn: 41.0205433	total: 10.9s	remaining: 1.52s
# 878:	learn: 41.0121240	total: 10.9s	remaining: 1.5s
# 879:	learn: 40.9807204	total: 10.9s	remaining: 1.49s
# 880:	learn: 40.9764307	total: 10.9s	remaining: 1.48s
# 881:	learn: 40.9561163	total: 11s	remaining: 1.47s
# 882:	learn: 40.9321691	total: 11s	remaining: 1.45s
# 883:	learn: 40.9000137	total: 11s	remaining: 1.44s
# 884:	learn: 40.8567022	total: 11s	remaining: 1.43s
# 885:	learn: 40.8546949	total: 11s	remaining: 1.41s
# 886:	learn: 40.8298231	total: 11s	remaining: 1.4s
# 887:	learn: 40.8175726	total: 11s	remaining: 1.39s
# 888:	learn: 40.7911843	total: 11s	remaining: 1.38s
# 889:	learn: 40.7793292	total: 11s	remaining: 1.36s
# 890:	learn: 40.7532908	total: 11s	remaining: 1.35s
# 891:	learn: 40.7454711	total: 11s	remaining: 1.34s
# 892:	learn: 40.7326462	total: 11.1s	remaining: 1.32s
# 893:	learn: 40.7229302	total: 11.1s	remaining: 1.31s
# 894:	learn: 40.6836364	total: 11.1s	remaining: 1.3s
# 895:	learn: 40.6759234	total: 11.1s	remaining: 1.29s
# 896:	learn: 40.6744235	total: 11.1s	remaining: 1.27s
# 897:	learn: 40.6524032	total: 11.1s	remaining: 1.26s
# 898:	learn: 40.6409686	total: 11.1s	remaining: 1.25s
# 899:	learn: 40.6286341	total: 11.1s	remaining: 1.24s
# 900:	learn: 40.6059655	total: 11.1s	remaining: 1.22s
# 901:	learn: 40.6003299	total: 11.2s	remaining: 1.21s
# 902:	learn: 40.5548584	total: 11.2s	remaining: 1.2s
# 903:	learn: 40.5186849	total: 11.2s	remaining: 1.19s
# 904:	learn: 40.4794860	total: 11.2s	remaining: 1.17s
# 905:	learn: 40.4539183	total: 11.2s	remaining: 1.16s
# 906:	learn: 40.4235587	total: 11.2s	remaining: 1.15s
# 907:	learn: 40.3905501	total: 11.2s	remaining: 1.14s
# 908:	learn: 40.3623610	total: 11.3s	remaining: 1.13s
# 909:	learn: 40.3524550	total: 11.3s	remaining: 1.12s
# 910:	learn: 40.3101913	total: 11.3s	remaining: 1.1s
# 911:	learn: 40.3084245	total: 11.3s	remaining: 1.09s
# 912:	learn: 40.3073108	total: 11.3s	remaining: 1.08s
# 913:	learn: 40.2792445	total: 11.4s	remaining: 1.07s
# 914:	learn: 40.2704000	total: 11.4s	remaining: 1.06s
# 915:	learn: 40.2574328	total: 11.4s	remaining: 1.05s
# 916:	learn: 40.2237867	total: 11.4s	remaining: 1.04s
# 917:	learn: 40.2018243	total: 11.5s	remaining: 1.02s
# 918:	learn: 40.1885042	total: 11.5s	remaining: 1.01s
# 919:	learn: 40.1644149	total: 11.5s	remaining: 998ms
# 920:	learn: 40.1523781	total: 11.5s	remaining: 986ms
# 921:	learn: 40.1264059	total: 11.5s	remaining: 973ms
# 922:	learn: 40.1102817	total: 11.5s	remaining: 960ms
# 923:	learn: 40.0922857	total: 11.5s	remaining: 947ms
# 924:	learn: 40.0720584	total: 11.5s	remaining: 935ms
# 925:	learn: 40.0392291	total: 11.5s	remaining: 922ms
# 926:	learn: 40.0010117	total: 11.5s	remaining: 909ms
# 927:	learn: 39.9613618	total: 11.6s	remaining: 897ms
# 928:	learn: 39.9480652	total: 11.6s	remaining: 884ms
# 929:	learn: 39.9135547	total: 11.6s	remaining: 871ms
# 930:	learn: 39.9006068	total: 11.6s	remaining: 859ms
# 931:	learn: 39.8732758	total: 11.6s	remaining: 847ms
# 932:	learn: 39.8542288	total: 11.6s	remaining: 835ms
# 933:	learn: 39.8314754	total: 11.6s	remaining: 822ms
# 934:	learn: 39.8228879	total: 11.7s	remaining: 810ms
# 935:	learn: 39.7783914	total: 11.7s	remaining: 797ms
# 936:	learn: 39.7727264	total: 11.7s	remaining: 785ms
# 937:	learn: 39.7405661	total: 11.7s	remaining: 772ms
# 938:	learn: 39.7033145	total: 11.7s	remaining: 760ms
# 939:	learn: 39.6657273	total: 11.7s	remaining: 747ms
# 940:	learn: 39.6599178	total: 11.7s	remaining: 735ms
# 941:	learn: 39.6388403	total: 11.7s	remaining: 723ms
# 942:	learn: 39.6228140	total: 11.8s	remaining: 711ms
# 943:	learn: 39.6076032	total: 11.8s	remaining: 699ms
# 944:	learn: 39.5795681	total: 11.8s	remaining: 686ms
# 945:	learn: 39.5616679	total: 11.8s	remaining: 674ms
# 946:	learn: 39.5473100	total: 11.8s	remaining: 662ms
# 947:	learn: 39.5230007	total: 11.8s	remaining: 649ms
# 948:	learn: 39.5164560	total: 11.8s	remaining: 636ms
# 949:	learn: 39.5021629	total: 11.9s	remaining: 624ms
# 950:	learn: 39.4933899	total: 11.9s	remaining: 611ms
# 951:	learn: 39.4590583	total: 11.9s	remaining: 599ms
# 952:	learn: 39.4384420	total: 11.9s	remaining: 586ms
# 953:	learn: 39.4168640	total: 11.9s	remaining: 574ms
# 954:	learn: 39.3839700	total: 11.9s	remaining: 562ms
# 955:	learn: 39.3789808	total: 11.9s	remaining: 549ms
# 956:	learn: 39.3714004	total: 11.9s	remaining: 536ms
# 957:	learn: 39.3385099	total: 12s	remaining: 524ms
# 958:	learn: 39.3267486	total: 12s	remaining: 511ms
# 959:	learn: 39.3182696	total: 12s	remaining: 499ms
# 960:	learn: 39.3092785	total: 12s	remaining: 487ms
# 961:	learn: 39.2841609	total: 12s	remaining: 474ms
# 962:	learn: 39.2736865	total: 12s	remaining: 462ms
# 963:	learn: 39.2433081	total: 12s	remaining: 449ms
# 964:	learn: 39.2078148	total: 12s	remaining: 437ms
# 965:	learn: 39.1744472	total: 12s	remaining: 424ms
# 966:	learn: 39.1533460	total: 12.1s	remaining: 411ms
# 967:	learn: 39.1157026	total: 12.1s	remaining: 399ms
# 968:	learn: 39.0896173	total: 12.1s	remaining: 386ms
# 969:	learn: 39.0810678	total: 12.1s	remaining: 374ms
# 970:	learn: 39.0473558	total: 12.1s	remaining: 361ms
# 971:	learn: 39.0230195	total: 12.1s	remaining: 349ms
# 972:	learn: 38.9835166	total: 12.1s	remaining: 336ms
# 973:	learn: 38.9402788	total: 12.1s	remaining: 324ms
# 974:	learn: 38.9021523	total: 12.1s	remaining: 311ms
# 975:	learn: 38.8662017	total: 12.2s	remaining: 299ms
# 976:	learn: 38.8390184	total: 12.2s	remaining: 286ms
# 977:	learn: 38.8192986	total: 12.2s	remaining: 274ms
# 978:	learn: 38.8067591	total: 12.2s	remaining: 261ms
# 979:	learn: 38.7880109	total: 12.2s	remaining: 249ms
# 980:	learn: 38.7664841	total: 12.2s	remaining: 236ms
# 981:	learn: 38.7601362	total: 12.2s	remaining: 224ms
# 982:	learn: 38.7374394	total: 12.2s	remaining: 211ms
# 983:	learn: 38.7081476	total: 12.2s	remaining: 199ms
# 984:	learn: 38.7071661	total: 12.2s	remaining: 186ms
# 985:	learn: 38.6820742	total: 12.3s	remaining: 174ms
# 986:	learn: 38.6503927	total: 12.3s	remaining: 162ms
# 987:	learn: 38.6009289	total: 12.3s	remaining: 149ms
# 988:	learn: 38.5631855	total: 12.3s	remaining: 137ms
# 989:	learn: 38.5577520	total: 12.3s	remaining: 124ms
# 990:	learn: 38.5254009	total: 12.3s	remaining: 112ms
# 991:	learn: 38.5037999	total: 12.3s	remaining: 99.5ms
# 992:	learn: 38.5028516	total: 12.3s	remaining: 87.1ms
# 993:	learn: 38.4865352	total: 12.4s	remaining: 74.6ms
# 994:	learn: 38.4612326	total: 12.4s	remaining: 62.2ms
# 995:	learn: 38.4367856	total: 12.4s	remaining: 49.8ms
# 996:	learn: 38.3839152	total: 12.4s	remaining: 37.3ms
# 997:	learn: 38.3680714	total: 12.4s	remaining: 24.9ms
# 998:	learn: 38.3548285	total: 12.4s	remaining: 12.4ms
# 999:	learn: 38.3287632	total: 12.4s	remaining: 0us
# RMSE Model <catboost.core.CatBoostRegressor object at 0x00000268C79A3760>: 73.48080084195608
# R2 Model <catboost.core.CatBoostRegressor object at 0x00000268C79A3760>: 0.5911139371831781

# %%
'''models = [lasso, ridge, elastic, svr, rfr, etr, gbr, xgbr, lgbmr, ctr]

for m in models:
    
    m.fit(X, y)
    
    y_pred = m.predict(X)
    
    print(f'RMSE Model {m}: {mse(y, y_pred, squared=False)}')'''

# %%
'''X = train1.drop('price', axis=1)

y = train1.price

lasso.fit(X, y)

y_pred = lasso.predict(test1)

sample1.price = y_pred

sample1.to_csv('../data/predictions.csv', index=False)

sample1'''

# %%
# H2O

h2o.init()

# parsear datos para h20

h2train=h2o.H2OFrame(train1)

h2test=h2o.H2OFrame(test1)

X=[c for c in h2train.columns if c!='price']

y='price'

# inicia auto-machine-learning

automl=H2OAutoML(max_models=50,
                 seed=42,
                 max_runtime_secs=300,
                 sort_metric='RMSE')

# %%
# entrena

automl.train(x=X,
             y=y,
             training_frame=h2train)

# %%
# prediciones del lider

y_pred = automl.leader.predict(h2test)

y_pred = y_pred.as_data_frame()

sample1.price = y_pred

sample1.to_csv('../data/predictions.csv', index=False)

sample1

# %%
# buscando colinealidad

plt.figure(figsize=(200, 200))

sns.set(style='white')

mask=np.triu(np.ones_like(train1.corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)

sns.heatmap(train1.corr(),
            mask=mask,
            cmap=cmap,
            center=0,
            square=True,
            linewidths=0.5,
            cbar_kws={'shrink': 0.5},
            annot=True);

# %%
train1.corr()

# %%
train.corr().price
